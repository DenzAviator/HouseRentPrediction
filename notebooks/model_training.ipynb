# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("./data/HouseRentPrediction.csv")

# %%
df.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# ...

# %%
#df=df.drop(labels=["Floor"],axis=1)
#df=df.drop(labels=["Posted On"],axis=1)
#df=df.drop(labels=["Area Locality"],axis=1)

# %%
df=df.drop(labels=["Floor","Posted On","Area Locality"],axis=1)

# %%
df.head()
# Out:
#    BHK   Rent  Size    Area Type     City Furnishing Status  Tenant Preferred  \
# 0    2  10000  1100   Super Area  Kolkata       Unfurnished  Bachelors/Family
# 1    2  20000   800   Super Area  Kolkata    Semi-Furnished  Bachelors/Family
# 2    2  17000  1000   Super Area  Kolkata    Semi-Furnished  Bachelors/Family
# 3    2  10000   800   Super Area  Kolkata       Unfurnished  Bachelors/Family
# 4    2   7500   850  Carpet Area  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# 4         1    Contact Owner

# %%
df.columns
# Out:
# Index(['BHK', 'Rent', 'Size', 'Area Type', 'City', 'Furnishing Status',
#        'Tenant Preferred', 'Bathroom', 'Point of Contact'],
#       dtype='object')

# %%
x=df.drop(labels=["Rent"],axis=1)

# %%
y=df[["Rent"]]

# %%
x
# Out:
#       BHK  Size    Area Type       City Furnishing Status  Tenant Preferred  \
# 0       2  1100   Super Area    Kolkata       Unfurnished  Bachelors/Family
# 1       2   800   Super Area    Kolkata    Semi-Furnished  Bachelors/Family
# 2       2  1000   Super Area    Kolkata    Semi-Furnished  Bachelors/Family
# 3       2   800   Super Area    Kolkata       Unfurnished  Bachelors/Family
# 4       2   850  Carpet Area    Kolkata       Unfurnished         Bachelors
# ...   ...   ...          ...        ...               ...               ...
# 4741    2  1000  Carpet Area  Hyderabad    Semi-Furnished  Bachelors/Family
# 4742    3  2000   Super Area  Hyderabad    Semi-Furnished  Bachelors/Family
# 4743    3  1750  Carpet Area  Hyderabad    Semi-Furnished  Bachelors/Family
# 4744    3  1500  Carpet Area  Hyderabad    Semi-Furnished            Family
# 4745    2  1000  Carpet Area  Hyderabad       Unfurnished         Bachelors
#
#       Bathroom Point of Contact
# ...

# %%
y
# Out:
#        Rent
# 0     10000
# 1     20000
# 2     17000
# 3     10000
# 4      7500
# ...     ...
# 4741  15000
# 4742  29000
# 4743  35000
# 4744  45000
# 4745  15000
#
# [4746 rows x 1 columns]

# %%
categorical_cols=x.select_dtypes(include="object").columns

# %%
numerical_cols=x.select_dtypes(exclude="object").columns

# %%
x.select_dtypes(include="object")
# Out:
#         Area Type       City Furnishing Status  Tenant Preferred  \
# 0      Super Area    Kolkata       Unfurnished  Bachelors/Family
# 1      Super Area    Kolkata    Semi-Furnished  Bachelors/Family
# 2      Super Area    Kolkata    Semi-Furnished  Bachelors/Family
# 3      Super Area    Kolkata       Unfurnished  Bachelors/Family
# 4     Carpet Area    Kolkata       Unfurnished         Bachelors
# ...           ...        ...               ...               ...
# 4741  Carpet Area  Hyderabad    Semi-Furnished  Bachelors/Family
# 4742   Super Area  Hyderabad    Semi-Furnished  Bachelors/Family
# 4743  Carpet Area  Hyderabad    Semi-Furnished  Bachelors/Family
# 4744  Carpet Area  Hyderabad    Semi-Furnished            Family
# 4745  Carpet Area  Hyderabad       Unfurnished         Bachelors
#
#      Point of Contact
# 0       Contact Owner
# 1       Contact Owner
# 2       Contact Owner
# 3       Contact Owner
# 4       Contact Owner
# ...               ...
# ...

# %%
y.select_dtypes(exclude="object").columns
# Out:
# Index(['Rent'], dtype='object')

# %%
categorical_cols
# Out:
# Index(['Area Type', 'City', 'Furnishing Status', 'Tenant Preferred',
#        'Point of Contact'],
#       dtype='object')

# %%
numerical_cols
# Out:
# Index(['BHK', 'Size', 'Bathroom'], dtype='object')

# %%
y.select_dtypes(include!="object")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Projects\HouseRentPrediction\notebooks\model_training.ipynb Cell 19 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Projects/HouseRentPrediction/notebooks/model_training.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> y.select_dtypes(include!="object")
#
# NameError: name 'include' is not defined
